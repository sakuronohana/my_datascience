# %% [markdown]
# <a href="https://colab.research.google.com/github/sakuronohana/my_datascience/blob/master/da_convid-19_vs_influenza/convid-19-analyse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Convid-19 Analyse#

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import datetime

cv19_conf_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'
cv19_death_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv'
cv19_recy_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv'

cv19confdat = pd.read_csv(cv19_conf_url)
cv19deathdat = pd.read_csv(cv19_death_url)
cv19recy = pd.read_csv(cv19_recy_url)


cv19confdat.groupby('Country/Region').mean()
# Out:
#                                     Lat      Long  ...  3/14/20  3/15/20
# Country/Region                                     ...
# Afghanistan                     33.0000   65.0000  ...     11.0     16.0
# Albania                         41.1533   20.1683  ...     38.0     42.0
# Algeria                         28.0339    1.6596  ...     37.0     48.0
# Andorra                         42.5063    1.5218  ...      1.0      1.0
# Antigua and Barbuda             17.0608  -61.7964  ...      1.0      1.0
# ...                                 ...       ...  ...      ...      ...
# Uruguay                        -32.5228  -55.7658  ...      4.0      4.0
# Uzbekistan                      41.3775   64.5853  ...      0.0      1.0
# Venezuela                        6.4238  -66.5897  ...      2.0     10.0
# Vietnam                         16.0000  108.0000  ...     53.0     56.0
# occupied Palestinian territory  31.9522   35.2332  ...      0.0      0.0
#
# [147 rows x 56 columns]

# %% [markdown]
# ###Berechnung CONVID-19 Mortalitätsrate pro betroffenes Land###

# %%
cv19deathdat
# Out:
#                      Country/Region  1/22/20  ...  3/14/20  3/15/20
# 26                      Afghanistan        0  ...        0        0
# 96                          Albania        0  ...        1        1
# 29                          Algeria        0  ...        3        4
# 61                          Andorra        0  ...        0        0
# 418             Antigua and Barbuda        0  ...        0        0
# ..                              ...      ...  ...      ...      ...
# 420                         Uruguay        0  ...        0        0
# 449                      Uzbekistan        0  ...        0        0
# 427                       Venezuela        0  ...        0        0
# 192                         Vietnam        0  ...        0        0
# 439  occupied Palestinian territory        0  ...        0        0
#
# [450 rows x 55 columns]

# %%
cv19chinaconv = cv19confdat.copy()
cv19chinadeath = cv19deathdat.copy()

cv19mortrate = pd.DataFrame([])

cv19chinaconv = cv19confdat[cv19confdat['Country/Region'] == 'China'].drop(['Province/State','Country/Region','Lat','Long'],axis=1)
cv19chinadeath = cv19deathdat[cv19deathdat['Country/Region'] == 'China'].drop(['Province/State','Country/Region','Lat','Long'],axis=1)

for i in cv19chinaconv.columns:
  result = round((cv19chinadeath[str(i)].sum()*100)/cv19chinaconv[str(i)].sum(),2)
  resultout = i,result
  cv19mortrate = p

# %%
resultout
# Out:
# ('3/15/20', 3.95)

# %%
ch_conf = cv19confdat[cv19confdat['Country/Region'] == 'Switzerland']
ch_conf = ch_conf.drop(['Province/State',	'Country/Region',	'Lat',	'Long'],axis=1)

ch_conf_dat = ['2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
       '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
       '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-a58d83d494fc> in <module>()
#       8
#       9 for i in ch_conf:
# ---> 10   if ch_conf[ch_conf[i] < 0]:
#      11     print(i)
#      12
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
